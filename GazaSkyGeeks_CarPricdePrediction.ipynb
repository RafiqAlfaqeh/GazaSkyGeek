# %% [markdown]
# <a href="https://colab.research.google.com/github/RafiqAlfaqeh/GazaSkyGeek/blob/main/GazaSkyGeeks_CarPricdePrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')

#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

cars = pd.read_csv('/content/CarPrice_Assignment.csv')
cars.tail(100)
# Out:
#      car_ID  symboling           CarName fueltype aspiration doornumber  \
# 105     106          3      nissan kicks      gas      turbo        two
# 106     107          1    nissan clipper      gas        std        two
# 107     108          0       peugeot 504      gas        std       four
# 108     109          0       peugeot 304   diesel      turbo       four
# 109     110          0  peugeot 504 (sw)      gas        std       four
# ..      ...        ...               ...      ...        ...        ...
# 200     201         -1   volvo 145e (sw)      gas        std       four
# 201     202         -1       volvo 144ea      gas      turbo       four
# 202     203         -1       volvo 244dl      gas        std       four
# 203     204         -1         volvo 246   diesel      turbo       four
# 204     205         -1       volvo 264gl      gas      turbo       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# ...
